# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import Requests Library and weather_api_key 6.2.6
import requests
from config import weather_api_key

# %%
# Build the basic URL for the OpenWeatherMay with your weather_api_key added to the URL.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. 
coordinates = list(lat_lngs)

# %%
# Import citipy.
from citipy import citipy

# %%
# Create a list for holding the cities. 
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list to get teh index of the city for logging.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        weather_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Weather Description": weather_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | geraldton
# Processing Record 2 of Set 16 | rikitea
# Processing Record 3 of Set 16 | kapaa
# Processing Record 4 of Set 16 | puerto ayora
# Processing Record 5 of Set 16 | mataura
# Processing Record 6 of Set 16 | kruisfontein
# Processing Record 7 of Set 16 | jamestown
# Processing Record 8 of Set 16 | hilo
# Processing Record 9 of Set 16 | rawson
# Processing Record 10 of Set 16 | paranaiba
# Processing Record 11 of Set 16 | srednekolymsk
# Processing Record 12 of Set 16 | yellowknife
# Processing Record 13 of Set 16 | muros
# Processing Record 14 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 16 | caiaponia
# Processing Record 16 of Set 16 | hermanus
# Processing Record 17 of Set 16 | klyuchi
# Processing Record 18 of Set 16 | busselton
# Processing Record 19 of Set 16 | north branch
# Processing Record 20 of Set 16 | ponta do sol
# Processing Record 21 of Set 16 | kodiak
# Processing Record 22 of Set 16 | sonqar
# City not found. Skipping...
# Processing Record 23 of Set 16 | severo-kurilsk
# Processing Record 24 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 16 | bermejo
# Processing Record 26 of Set 16 | cabimas
# Processing Record 27 of Set 16 | bluff
# Processing Record 28 of Set 16 | porbandar
# Processing Record 29 of Set 16 | milledgeville
# Processing Record 30 of Set 16 | tuktoyaktuk
# Processing Record 31 of Set 16 | grindavik
# Processing Record 32 of Set 16 | talnakh
# Processing Record 33 of Set 16 | nikolskoye
# Processing Record 34 of Set 16 | albany
# Processing Record 35 of Set 16 | kaitangata
# Processing Record 36 of Set 16 | hithadhoo
# Processing Record 37 of Set 16 | batagay
# Processing Record 38 of Set 16 | horasan
# Processing Record 39 of Set 16 | qaanaaq
# Processing Record 40 of Set 16 | lavrentiya
# Processing Record 41 of Set 16 | falun
# Processing Record 42 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 16 | new norfolk
# Processing Record 44 of Set 16 | norman wells
# Processing Record 45 of Set 16 | provideniya
# Processing Record 46 of Set 16 | mudgee
# Processing Record 47 of Set 16 | beringovskiy
# Processing Record 48 of Set 16 | labuhan
# Processing Record 49 of Set 16 | saint-pierre
# Processing Record 50 of Set 16 | santa rosa
# Processing Record 1 of Set 17 | port elizabeth
# Processing Record 2 of Set 17 | saint-francois
# Processing Record 3 of Set 17 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 17 | harper
# Processing Record 5 of Set 17 | atuona
# Processing Record 6 of Set 17 | sinnamary
# Processing Record 7 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 17 | souillac
# Processing Record 9 of Set 17 | pisco
# Processing Record 10 of Set 17 | carnarvon
# Processing Record 11 of Set 17 | saint-philippe
# Processing Record 12 of Set 17 | arona
# Processing Record 13 of Set 17 | sao paulo de olivenca
# Processing Record 14 of Set 17 | tlachichuca
# Processing Record 15 of Set 17 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 17 | cape town
# Processing Record 17 of Set 17 | paka
# Processing Record 18 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 17 | vaini
# Processing Record 20 of Set 17 | bandarbeyla
# Processing Record 21 of Set 17 | cidreira
# Processing Record 22 of Set 17 | kudahuvadhoo
# Processing Record 23 of Set 17 | yilan
# Processing Record 24 of Set 17 | hambantota
# Processing Record 25 of Set 17 | leh
# Processing Record 26 of Set 17 | ushuaia
# Processing Record 27 of Set 17 | weligama
# Processing Record 28 of Set 17 | taoudenni
# Processing Record 29 of Set 17 | acapulco
# Processing Record 30 of Set 17 | vilyuysk
# Processing Record 31 of Set 17 | butaritari
# Processing Record 32 of Set 17 | sisimiut
# Processing Record 33 of Set 17 | punta arenas
# Processing Record 34 of Set 17 | tual
# Processing Record 35 of Set 17 | mahebourg
# Processing Record 36 of Set 17 | nanortalik
# Processing Record 37 of Set 17 | hamilton
# Processing Record 38 of Set 17 | wau
# Processing Record 39 of Set 17 | iqaluit
# Processing Record 40 of Set 17 | mecca
# Processing Record 41 of Set 17 | clyde river
# Processing Record 42 of Set 17 | ranong
# Processing Record 43 of Set 17 | hirara
# Processing Record 44 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 17 | kapiri mposhi
# Processing Record 46 of Set 17 | salalah
# Processing Record 47 of Set 17 | georgetown
# Processing Record 48 of Set 17 | caravelas
# Processing Record 49 of Set 17 | saskylakh
# Processing Record 50 of Set 17 | tuzha
# Processing Record 1 of Set 18 | bethel
# Processing Record 2 of Set 18 | pevek
# Processing Record 3 of Set 18 | arraial do cabo
# Processing Record 4 of Set 18 | komsomolskiy
# Processing Record 5 of Set 18 | verkhnevilyuysk
# Processing Record 6 of Set 18 | bengkulu
# Processing Record 7 of Set 18 | grand gaube
# Processing Record 8 of Set 18 | flinders
# Processing Record 9 of Set 18 | narsaq
# Processing Record 10 of Set 18 | bredasdorp
# Processing Record 11 of Set 18 | chabahar
# Processing Record 12 of Set 18 | misratah
# Processing Record 13 of Set 18 | leamington
# Processing Record 14 of Set 18 | batemans bay
# Processing Record 15 of Set 18 | klaksvik
# Processing Record 16 of Set 18 | te anau
# Processing Record 17 of Set 18 | chokurdakh
# Processing Record 18 of Set 18 | penapolis
# Processing Record 19 of Set 18 | lagoa
# Processing Record 20 of Set 18 | coahuayana
# Processing Record 21 of Set 18 | anaconda
# Processing Record 22 of Set 18 | broken hill
# Processing Record 23 of Set 18 | aberdeen
# Processing Record 24 of Set 18 | sukabumi
# Processing Record 25 of Set 18 | airai
# Processing Record 26 of Set 18 | port alfred
# Processing Record 27 of Set 18 | tasiilaq
# Processing Record 28 of Set 18 | kizukuri
# Processing Record 29 of Set 18 | saldanha
# Processing Record 30 of Set 18 | alofi
# Processing Record 31 of Set 18 | cairns
# Processing Record 32 of Set 18 | noyabrsk
# Processing Record 33 of Set 18 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 18 | miri
# Processing Record 35 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 18 | kulhudhuffushi
# Processing Record 37 of Set 18 | dikson
# Processing Record 38 of Set 18 | thompson
# Processing Record 39 of Set 18 | wasilla
# Processing Record 40 of Set 18 | portland
# Processing Record 41 of Set 18 | gumushane
# City not found. Skipping...
# Processing Record 42 of Set 18 | port hardy
# Processing Record 43 of Set 18 | isiro
# Processing Record 44 of Set 18 | cherskiy
# Processing Record 45 of Set 18 | kimbe
# Processing Record 46 of Set 18 | kavaratti
# Processing Record 47 of Set 18 | nouadhibou
# Processing Record 48 of Set 18 | ust-tsilma
# Processing Record 49 of Set 18 | namatanai
# Processing Record 50 of Set 18 | jatiroto
# Processing Record 1 of Set 19 | barinas
# Processing Record 2 of Set 19 | avarua
# Processing Record 3 of Set 19 | lazaro cardenas
# Processing Record 4 of Set 19 | malartic
# Processing Record 5 of Set 19 | la ronge
# Processing Record 6 of Set 19 | namibe
# Processing Record 7 of Set 19 | udachnyy
# Processing Record 8 of Set 19 | le vauclin
# Processing Record 9 of Set 19 | shetpe
# Processing Record 10 of Set 19 | tripoli
# Processing Record 11 of Set 19 | sitka
# Processing Record 12 of Set 19 | whitehorse
# Processing Record 13 of Set 19 | ilulissat
# Processing Record 14 of Set 19 | los llanos de aridane
# Processing Record 15 of Set 19 | castro
# Processing Record 16 of Set 19 | dzilam gonzalez
# Processing Record 17 of Set 19 | morondava
# Processing Record 18 of Set 19 | okha
# Processing Record 19 of Set 19 | muscat
# Processing Record 20 of Set 19 | tiksi
# Processing Record 21 of Set 19 | upernavik
# Processing Record 22 of Set 19 | dingle
# Processing Record 23 of Set 19 | camacha
# Processing Record 24 of Set 19 | vestmannaeyjar
# Processing Record 25 of Set 19 | east london
# Processing Record 26 of Set 19 | paarl
# Processing Record 27 of Set 19 | khatanga
# Processing Record 28 of Set 19 | biltine
# Processing Record 29 of Set 19 | abiy adi
# City not found. Skipping...
# Processing Record 30 of Set 19 | amilly
# Processing Record 31 of Set 19 | marandahalli
# Processing Record 32 of Set 19 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 19 | carson city
# Processing Record 34 of Set 19 | bonfim
# Processing Record 35 of Set 19 | great yarmouth
# Processing Record 36 of Set 19 | ribeira grande
# Processing Record 37 of Set 19 | tarakan
# Processing Record 38 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 19 | shawinigan
# Processing Record 40 of Set 19 | olafsvik
# Processing Record 41 of Set 19 | okhotsk
# Processing Record 42 of Set 19 | arlit
# Processing Record 43 of Set 19 | fortuna
# Processing Record 44 of Set 19 | makakilo city
# Processing Record 45 of Set 19 | nome
# Processing Record 46 of Set 19 | kununurra
# Processing Record 47 of Set 19 | doha
# Processing Record 48 of Set 19 | kutum
# Processing Record 49 of Set 19 | daru
# Processing Record 50 of Set 19 | angouleme
# Processing Record 1 of Set 20 | sungaipenuh
# Processing Record 2 of Set 20 | duz
# City not found. Skipping...
# Processing Record 3 of Set 20 | sar-e pul
# Processing Record 4 of Set 20 | waingapu
# Processing Record 5 of Set 20 | pokhara
# Processing Record 6 of Set 20 | bafata
# Processing Record 7 of Set 20 | vysokogornyy
# Processing Record 8 of Set 20 | pasighat
# Processing Record 9 of Set 20 | zhumadian
# Processing Record 10 of Set 20 | vila franca do campo
# Processing Record 11 of Set 20 | price
# Processing Record 12 of Set 20 | le pradet
# Processing Record 13 of Set 20 | rio grande
# Processing Record 14 of Set 20 | merauke
# Processing Record 15 of Set 20 | pochutla
# Processing Record 16 of Set 20 | bambous virieux
# Processing Record 17 of Set 20 | ancud
# Processing Record 18 of Set 20 | victoria
# Processing Record 19 of Set 20 | coquimbo
# Processing Record 20 of Set 20 | hobart
# Processing Record 21 of Set 20 | saint-augustin
# Processing Record 22 of Set 20 | union
# Processing Record 23 of Set 20 | havre-saint-pierre
# Processing Record 24 of Set 20 | manokwari
# Processing Record 25 of Set 20 | zunyi
# Processing Record 26 of Set 20 | petauke
# Processing Record 27 of Set 20 | letlhakane
# Processing Record 28 of Set 20 | altamont
# Processing Record 29 of Set 20 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 20 | divnogorsk
# Processing Record 31 of Set 20 | guerrero negro
# Processing Record 32 of Set 20 | mandera
# Processing Record 33 of Set 20 | belaya gora
# Processing Record 34 of Set 20 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 20 | sosnovo-ozerskoye
# Processing Record 36 of Set 20 | alta floresta
# Processing Record 37 of Set 20 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 20 | viesca
# Processing Record 39 of Set 20 | yar-sale
# Processing Record 40 of Set 20 | husavik
# Processing Record 41 of Set 20 | luderitz
# Processing Record 42 of Set 20 | odweyne
# Processing Record 43 of Set 20 | babu
# Processing Record 44 of Set 20 | mount isa
# Processing Record 45 of Set 20 | flin flon
# Processing Record 46 of Set 20 | sabang
# Processing Record 47 of Set 20 | katha
# City not found. Skipping...
# Processing Record 48 of Set 20 | high wycombe
# Processing Record 49 of Set 20 | whithorn
# Processing Record 50 of Set 20 | barrow
# Processing Record 1 of Set 21 | panama city
# Processing Record 2 of Set 21 | falealupo
# City not found. Skipping...
# Processing Record 3 of Set 21 | riyadh
# Processing Record 4 of Set 21 | esperance
# Processing Record 5 of Set 21 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 21 | businga
# Processing Record 7 of Set 21 | sarkand
# Processing Record 8 of Set 21 | shimoda
# Processing Record 9 of Set 21 | saint-joseph
# Processing Record 10 of Set 21 | lichinga
# Processing Record 11 of Set 21 | atar
# Processing Record 12 of Set 21 | meaford
# Processing Record 13 of Set 21 | jalu
# Processing Record 14 of Set 21 | ruidoso
# Processing Record 15 of Set 21 | palu
# Processing Record 16 of Set 21 | itamarandiba
# Processing Record 17 of Set 21 | karratha
# Processing Record 18 of Set 21 | muroto
# Processing Record 19 of Set 21 | emilio carranza
# Processing Record 20 of Set 21 | hualmay
# Processing Record 21 of Set 21 | angoram
# Processing Record 22 of Set 21 | longido
# Processing Record 23 of Set 21 | itarema
# Processing Record 24 of Set 21 | evensk
# Processing Record 25 of Set 21 | grand island
# Processing Record 26 of Set 21 | kavieng
# Processing Record 27 of Set 21 | great falls
# Processing Record 28 of Set 21 | rosetta
# Processing Record 29 of Set 21 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 21 | kahului
# Processing Record 31 of Set 21 | armacao dos buzios
# City not found. Skipping...
# Processing Record 32 of Set 21 | bosaso
# Processing Record 33 of Set 21 | shizilu
# Processing Record 34 of Set 21 | nanyamba
# Processing Record 35 of Set 21 | berlevag
# Processing Record 36 of Set 21 | yenagoa
# Processing Record 37 of Set 21 | tuatapere
# Processing Record 38 of Set 21 | olinda
# Processing Record 39 of Set 21 | tera
# Processing Record 40 of Set 21 | redwater
# Processing Record 41 of Set 21 | plerin
# Processing Record 42 of Set 21 | atchison
# Processing Record 43 of Set 21 | torit
# Processing Record 44 of Set 21 | college
# Processing Record 45 of Set 21 | vostok
# Processing Record 46 of Set 21 | tecoanapa
# Processing Record 47 of Set 21 | roald
# Processing Record 48 of Set 21 | tura
# Processing Record 49 of Set 21 | lebu
# Processing Record 50 of Set 21 | tsienyane
# City not found. Skipping...
# Processing Record 1 of Set 22 | rixheim
# Processing Record 2 of Set 22 | najran
# Processing Record 3 of Set 22 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 22 | sarangani
# Processing Record 5 of Set 22 | mumford
# Processing Record 6 of Set 22 | mahenge
# Processing Record 7 of Set 22 | meulaboh
# Processing Record 8 of Set 22 | estevan
# Processing Record 9 of Set 22 | osa
# Processing Record 10 of Set 22 | la palma
# Processing Record 11 of Set 22 | mar del plata
# Processing Record 12 of Set 22 | port hawkesbury
# Processing Record 13 of Set 22 | chuy
# Processing Record 14 of Set 22 | kotma
# Processing Record 15 of Set 22 | masterton
# Processing Record 16 of Set 22 | san patricio
# Processing Record 17 of Set 22 | shwebo
# Processing Record 18 of Set 22 | morehead
# Processing Record 19 of Set 22 | westport
# Processing Record 20 of Set 22 | luancheng
# Processing Record 21 of Set 22 | laguna
# Processing Record 22 of Set 22 | waipawa
# Processing Record 23 of Set 22 | fairbanks
# Processing Record 24 of Set 22 | torbay
# Processing Record 25 of Set 22 | coihaique
# Processing Record 26 of Set 22 | kudat
# Processing Record 27 of Set 22 | port-gentil
# Processing Record 28 of Set 22 | hereford
# Processing Record 29 of Set 22 | porgera
# Processing Record 30 of Set 22 | mount gambier
# Processing Record 31 of Set 22 | hurghada
# Processing Record 32 of Set 22 | frunze
# Processing Record 33 of Set 22 | alice town
# Processing Record 34 of Set 22 | lompoc
# Processing Record 35 of Set 22 | longyearbyen
# Processing Record 36 of Set 22 | vardo
# Processing Record 37 of Set 22 | mazagao
# Processing Record 38 of Set 22 | sann
# Processing Record 39 of Set 22 | kedrovyy
# Processing Record 40 of Set 22 | asyut
# Processing Record 41 of Set 22 | artyom
# Processing Record 42 of Set 22 | kerteh
# City not found. Skipping...
# Processing Record 43 of Set 22 | saint george
# Processing Record 44 of Set 22 | teul
# City not found. Skipping...
# Processing Record 45 of Set 22 | poykovskiy
# Processing Record 46 of Set 22 | winnemucca
# Processing Record 47 of Set 22 | boende
# Processing Record 48 of Set 22 | omboue
# Processing Record 49 of Set 22 | rorvik
# Processing Record 50 of Set 22 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 23 | karauzyak
# City not found. Skipping...
# Processing Record 2 of Set 23 | iskateley
# Processing Record 3 of Set 23 | madang
# Processing Record 4 of Set 23 | alice springs
# Processing Record 5 of Set 23 | maputo
# Processing Record 6 of Set 23 | shache
# Processing Record 7 of Set 23 | trairi
# Processing Record 8 of Set 23 | deputatskiy
# Processing Record 9 of Set 23 | bajil
# Processing Record 10 of Set 23 | ponta delgada
# Processing Record 11 of Set 23 | ilinskiy
# Processing Record 12 of Set 23 | zaykovo
# Processing Record 13 of Set 23 | lilongwe
# Processing Record 14 of Set 23 | opuwo
# Processing Record 15 of Set 23 | bathsheba
# Processing Record 16 of Set 23 | ohafia
# Processing Record 17 of Set 23 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 23 | itupiranga
# Processing Record 19 of Set 23 | quatre cocos
# Processing Record 20 of Set 23 | vuktyl
# Processing Record 21 of Set 23 | majenang
# Processing Record 22 of Set 23 | stoyba
# City not found. Skipping...
# Processing Record 23 of Set 23 | carhuamayo
# Processing Record 24 of Set 23 | skibotn
# Processing Record 25 of Set 23 | adrar
# Processing Record 26 of Set 23 | mikhaylovka
# Processing Record 27 of Set 23 | hunza
# City not found. Skipping...
# Processing Record 28 of Set 23 | vao
# Processing Record 29 of Set 23 | chifeng
# Processing Record 30 of Set 23 | port lincoln
# Processing Record 31 of Set 23 | gimli
# Processing Record 32 of Set 23 | emerald
# Processing Record 33 of Set 23 | porto novo
# Processing Record 34 of Set 23 | sataua
# City not found. Skipping...
# Processing Record 35 of Set 23 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 23 | nuevo casas grandes
# Processing Record 37 of Set 23 | aklavik
# Processing Record 38 of Set 23 | manta
# Processing Record 39 of Set 23 | pali
# Processing Record 40 of Set 23 | fort nelson
# Processing Record 41 of Set 23 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 23 | luwuk
# Processing Record 43 of Set 23 | rocha
# Processing Record 44 of Set 23 | sobolevo
# Processing Record 45 of Set 23 | zatoka
# Processing Record 46 of Set 23 | birao
# Processing Record 47 of Set 23 | khani
# Processing Record 48 of Set 23 | pitimbu
# Processing Record 49 of Set 23 | ahipara
# Processing Record 50 of Set 23 | bulgan
# Processing Record 1 of Set 24 | red deer
# Processing Record 2 of Set 24 | bitung
# Processing Record 3 of Set 24 | boyuibe
# Processing Record 4 of Set 24 | port blair
# Processing Record 5 of Set 24 | banepa
# Processing Record 6 of Set 24 | lexington
# Processing Record 7 of Set 24 | constantine
# Processing Record 8 of Set 24 | praya
# Processing Record 9 of Set 24 | lasa
# Processing Record 10 of Set 24 | guanica
# Processing Record 11 of Set 24 | kurchum
# Processing Record 12 of Set 24 | reims
# Processing Record 13 of Set 24 | agdas
# Processing Record 14 of Set 24 | rock sound
# Processing Record 15 of Set 24 | sorland
# Processing Record 16 of Set 24 | toamasina
# Processing Record 17 of Set 24 | edgewater
# Processing Record 18 of Set 24 | bridgetown
# Processing Record 19 of Set 24 | holland
# Processing Record 20 of Set 24 | macomb
# Processing Record 21 of Set 24 | mindelo
# Processing Record 22 of Set 24 | jizan
# Processing Record 23 of Set 24 | oranjemund
# Processing Record 24 of Set 24 | burnie
# Processing Record 25 of Set 24 | lakatoro
# Processing Record 26 of Set 24 | beroroha
# Processing Record 27 of Set 24 | ossipee
# Processing Record 28 of Set 24 | kindu
# Processing Record 29 of Set 24 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 24 | rundu
# Processing Record 31 of Set 24 | guhagar
# Processing Record 32 of Set 24 | kumluca
# Processing Record 33 of Set 24 | bubaque
# Processing Record 34 of Set 24 | tessalit
# Processing Record 35 of Set 24 | marsa matruh
# Processing Record 36 of Set 24 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 24 | carballo
# Processing Record 38 of Set 24 | gibara
# Processing Record 39 of Set 24 | tecolutla
# Processing Record 40 of Set 24 | seoul
# Processing Record 41 of Set 24 | kardla
# Processing Record 42 of Set 24 | litoral del san juan
# City not found. Skipping...
# Processing Record 43 of Set 24 | somerset
# Processing Record 44 of Set 24 | majene
# Processing Record 45 of Set 24 | nishihara
# Processing Record 46 of Set 24 | san quintin
# Processing Record 47 of Set 24 | comodoro rivadavia
# Processing Record 48 of Set 24 | toftir
# City not found. Skipping...
# Processing Record 49 of Set 24 | limulunga
# Processing Record 50 of Set 24 | alexandria
# Processing Record 1 of Set 25 | santander
# Processing Record 2 of Set 25 | takoradi
# Processing Record 3 of Set 25 | raboso
# Processing Record 4 of Set 25 | along
# Processing Record 5 of Set 25 | bud
# Processing Record 6 of Set 25 | isangel
# Processing Record 7 of Set 25 | tateyama
# Processing Record 8 of Set 25 | axim
# Processing Record 9 of Set 25 | bolanos de calatrava
# Processing Record 10 of Set 25 | cap-aux-meules
# Processing Record 11 of Set 25 | adre
# Processing Record 12 of Set 25 | surgut
# Processing Record 13 of Set 25 | asosa
# Processing Record 14 of Set 25 | la libertad
# Processing Record 15 of Set 25 | gambela
# Processing Record 16 of Set 25 | srandakan
# Processing Record 17 of Set 25 | ulladulla
# Processing Record 18 of Set 25 | tete
# Processing Record 19 of Set 25 | chiang rai
# Processing Record 20 of Set 25 | sioux lookout
# Processing Record 21 of Set 25 | methoni
# Processing Record 22 of Set 25 | jamsa
# Processing Record 23 of Set 25 | bonavista
# Processing Record 24 of Set 25 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 25 | constitucion
# Processing Record 26 of Set 25 | mariana
# Processing Record 27 of Set 25 | bardiyah
# Processing Record 28 of Set 25 | moose factory
# Processing Record 29 of Set 25 | lorengau
# Processing Record 30 of Set 25 | machali
# Processing Record 31 of Set 25 | ubatuba
# Processing Record 32 of Set 25 | bintulu
# Processing Record 33 of Set 25 | marang
# Processing Record 34 of Set 25 | shakawe
# Processing Record 35 of Set 25 | platanos
# Processing Record 36 of Set 25 | devgarh
# Processing Record 37 of Set 25 | elizabeth city
# Processing Record 38 of Set 25 | kloulklubed
# Processing Record 39 of Set 25 | mailsi
# Processing Record 40 of Set 25 | iturama
# Processing Record 41 of Set 25 | katsuura
# Processing Record 42 of Set 25 | praia da vitoria
# Processing Record 43 of Set 25 | yangjiang
# Processing Record 44 of Set 25 | melsomvik
# Processing Record 45 of Set 25 | kysyl-syr
# Processing Record 46 of Set 25 | keningau
# Processing Record 47 of Set 25 | viedma
# Processing Record 48 of Set 25 | sedelnikovo
# City not found. Skipping...
# Processing Record 49 of Set 25 | kachug
# Processing Record 50 of Set 25 | neiafu
# Processing Record 1 of Set 26 | asau
# Processing Record 2 of Set 26 | san cristobal
# Processing Record 3 of Set 26 | stara synyava
# Processing Record 4 of Set 26 | nemuro
# Processing Record 5 of Set 26 | rosarito
# Processing Record 6 of Set 26 | yulara
# Processing Record 7 of Set 26 | kupang
# Processing Record 8 of Set 26 | cam pha
# City not found. Skipping...
# Processing Record 9 of Set 26 | srivardhan
# Processing Record 10 of Set 26 | santa ines
# Processing Record 11 of Set 26 | pau dos ferros
# Processing Record 12 of Set 26 | bereda
# Processing Record 13 of Set 26 | kailua
# Processing Record 14 of Set 26 | benguela
# Processing Record 15 of Set 26 | camacupa
# Processing Record 16 of Set 26 | prado
# Processing Record 17 of Set 26 | warrnambool
# Processing Record 18 of Set 26 | we
# City not found. Skipping...
# Processing Record 19 of Set 26 | boguchany
# Processing Record 20 of Set 26 | venado tuerto
# Processing Record 21 of Set 26 | talgar
# Processing Record 22 of Set 26 | moron
# Processing Record 23 of Set 26 | bakchar
# Processing Record 24 of Set 26 | piazza armerina
# Processing Record 25 of Set 26 | pangnirtung
# Processing Record 26 of Set 26 | oranjestad
# Processing Record 27 of Set 26 | ndiekro
# City not found. Skipping...
# Processing Record 28 of Set 26 | barbosa ferraz
# Processing Record 29 of Set 26 | bilibino
# Processing Record 30 of Set 26 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 26 | saharsa
# Processing Record 32 of Set 26 | bartlesville
# Processing Record 33 of Set 26 | cileunyi
# Processing Record 34 of Set 26 | high level
# Processing Record 35 of Set 26 | rantoul
# Processing Record 36 of Set 26 | mersing
# Processing Record 37 of Set 26 | kiunga
# Processing Record 38 of Set 26 | kasama
# Processing Record 39 of Set 26 | sola
# Processing Record 40 of Set 26 | hondo
# Processing Record 41 of Set 26 | qaqortoq
# Processing Record 42 of Set 26 | slave lake
# Processing Record 43 of Set 26 | praia
# Processing Record 44 of Set 26 | kalmunai
# Processing Record 45 of Set 26 | zharkent
# Processing Record 46 of Set 26 | khandyga
# Processing Record 47 of Set 26 | pangkalanbuun
# Processing Record 48 of Set 26 | katangli
# Processing Record 49 of Set 26 | igarka
# Processing Record 50 of Set 26 | salmas
# Processing Record 1 of Set 27 | bembereke
# Processing Record 2 of Set 27 | gryazovets
# Processing Record 3 of Set 27 | mmathubudukwane
# Processing Record 4 of Set 27 | shanhetun
# Processing Record 5 of Set 27 | charagua
# Processing Record 6 of Set 27 | chenzhou
# Processing Record 7 of Set 27 | jieshi
# Processing Record 8 of Set 27 | matay
# Processing Record 9 of Set 27 | bull savanna
# Processing Record 10 of Set 27 | odda
# Processing Record 11 of Set 27 | charters towers
# Processing Record 12 of Set 27 | moussoro
# Processing Record 13 of Set 27 | nelson bay
# Processing Record 14 of Set 27 | baykit
# Processing Record 15 of Set 27 | yumen
# Processing Record 16 of Set 27 | kaliua
# Processing Record 17 of Set 27 | kushmurun
# Processing Record 18 of Set 27 | orcopampa
# Processing Record 19 of Set 27 | batsfjord
# Processing Record 20 of Set 27 | cayenne
# Processing Record 21 of Set 27 | hasaki
# Processing Record 22 of Set 27 | dunedin
# Processing Record 23 of Set 27 | predivinsk
# Processing Record 24 of Set 27 | ucluelet
# Processing Record 25 of Set 27 | dembi dolo
# Processing Record 26 of Set 27 | kieta
# Processing Record 27 of Set 27 | tortoli
# Processing Record 28 of Set 27 | hobyo
# Processing Record 29 of Set 27 | impfondo
# Processing Record 30 of Set 27 | uray
# Processing Record 31 of Set 27 | leningradskiy
# Processing Record 32 of Set 27 | weatherford
# Processing Record 33 of Set 27 | norsup
# Processing Record 34 of Set 27 | faanui
# Processing Record 35 of Set 27 | zhangye
# Processing Record 36 of Set 27 | ames
# Processing Record 37 of Set 27 | marzuq
# Processing Record 38 of Set 27 | naze
# Processing Record 39 of Set 27 | annau
# Processing Record 40 of Set 27 | castlerea
# Processing Record 41 of Set 27 | greensburg
# Processing Record 42 of Set 27 | marmora
# Processing Record 43 of Set 27 | urumqi
# Processing Record 44 of Set 27 | codrington
# Processing Record 45 of Set 27 | killybegs
# Processing Record 46 of Set 27 | belyy yar
# Processing Record 47 of Set 27 | kamenka
# Processing Record 48 of Set 27 | babanusah
# City not found. Skipping...
# Processing Record 49 of Set 27 | ostrovnoy
# Processing Record 50 of Set 27 | tautira
# Processing Record 1 of Set 28 | black diamond
# Processing Record 2 of Set 28 | hay river
# Processing Record 3 of Set 28 | nalut
# Processing Record 4 of Set 28 | quarai
# Processing Record 5 of Set 28 | rodrigues alves
# Processing Record 6 of Set 28 | haines junction
# Processing Record 7 of Set 28 | kamina
# Processing Record 8 of Set 28 | dutse
# Processing Record 9 of Set 28 | rembang
# Processing Record 10 of Set 28 | oktyabrskiy
# Processing Record 11 of Set 28 | arco
# Processing Record 12 of Set 28 | paita
# Processing Record 13 of Set 28 | mareeba
# Processing Record 14 of Set 28 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 28 | nantucket
# Processing Record 16 of Set 28 | honningsvag
# Processing Record 17 of Set 28 | almaznyy
# Processing Record 18 of Set 28 | zhaocheng
# City not found. Skipping...
# Processing Record 19 of Set 28 | langsa
# Processing Record 20 of Set 28 | kyren
# Processing Record 21 of Set 28 | skagen
# Processing Record 22 of Set 28 | hebertville
# City not found. Skipping...
# Processing Record 23 of Set 28 | muncar
# Processing Record 24 of Set 28 | sens
# Processing Record 25 of Set 28 | pondicherry
# Processing Record 26 of Set 28 | gizo
# Processing Record 27 of Set 28 | worland
# Processing Record 28 of Set 28 | innisfail
# Processing Record 29 of Set 28 | cabildo
# Processing Record 30 of Set 28 | tazmalt
# Processing Record 31 of Set 28 | nkhotakota
# Processing Record 32 of Set 28 | lata
# Processing Record 33 of Set 28 | rio rancho
# Processing Record 34 of Set 28 | preobrazheniye
# Processing Record 35 of Set 28 | darhan
# Processing Record 36 of Set 28 | margate
# Processing Record 37 of Set 28 | mandi bahauddin
# Processing Record 38 of Set 28 | sao joao da barra
# Processing Record 39 of Set 28 | batagay-alyta
# Processing Record 40 of Set 28 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 28 | kalabo
# Processing Record 42 of Set 28 | multan
# Processing Record 43 of Set 28 | pacific grove
# Processing Record 44 of Set 28 | matara
# Processing Record 45 of Set 28 | cabo san lucas
# Processing Record 46 of Set 28 | yarim
# Processing Record 47 of Set 28 | sur
# Processing Record 48 of Set 28 | caruray
# Processing Record 49 of Set 28 | calama
# Processing Record 50 of Set 28 | wenling
# Processing Record 1 of Set 29 | la seyne-sur-mer
# Processing Record 2 of Set 29 | sao jose da coroa grande
# Processing Record 3 of Set 29 | fox lake
# Processing Record 4 of Set 29 | tapaua
# City not found. Skipping...
# Processing Record 5 of Set 29 | papetoai
# Processing Record 6 of Set 29 | matata
# Processing Record 7 of Set 29 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 29 | hazorasp
# Processing Record 9 of Set 29 | sindor
# Processing Record 10 of Set 29 | orotukan
# Processing Record 11 of Set 29 | suntar
# Processing Record 12 of Set 29 | ixtapa
# Processing Record 13 of Set 29 | kingman
# Processing Record 14 of Set 29 | katherine
# Processing Record 15 of Set 29 | broome
# Processing Record 16 of Set 29 | lazarev
# Processing Record 17 of Set 29 | chumikan
# Processing Record 18 of Set 29 | malpe
# Processing Record 19 of Set 29 | shelburne
# Processing Record 20 of Set 29 | lar
# Processing Record 21 of Set 29 | jimalalud
# Processing Record 22 of Set 29 | tomatlan
# Processing Record 23 of Set 29 | nara
# Processing Record 24 of Set 29 | joensuu
# Processing Record 25 of Set 29 | manyana
# Processing Record 26 of Set 29 | teya
# Processing Record 27 of Set 29 | bodaybo
# Processing Record 28 of Set 29 | zhaotong
# Processing Record 29 of Set 29 | benito juarez
# Processing Record 30 of Set 29 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 29 | kijang
# Processing Record 32 of Set 29 | buzmeyin
# Processing Record 33 of Set 29 | nogliki
# Processing Record 34 of Set 29 | tailai
# Processing Record 35 of Set 29 | hohhot
# Processing Record 36 of Set 29 | sovetskiy
# Processing Record 37 of Set 29 | tombouctou
# Processing Record 38 of Set 29 | san policarpo
# Processing Record 39 of Set 29 | hervey bay
# Processing Record 40 of Set 29 | tobane
# Processing Record 41 of Set 29 | sechura
# Processing Record 42 of Set 29 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 29 | tukan
# Processing Record 44 of Set 29 | uinskoye
# Processing Record 45 of Set 29 | santo antonio do monte
# Processing Record 46 of Set 29 | kayerkan
# Processing Record 47 of Set 29 | kemptville
# Processing Record 48 of Set 29 | salme
# Processing Record 49 of Set 29 | marrakesh
# Processing Record 50 of Set 29 | north myrtle beach
# Processing Record 1 of Set 30 | chingirlau
# Processing Record 2 of Set 30 | vanavara
# Processing Record 3 of Set 30 | rockland
# Processing Record 4 of Set 30 | mayo
# Processing Record 5 of Set 30 | darnetal
# Processing Record 6 of Set 30 | moerai
# Processing Record 7 of Set 30 | tacoronte
# Processing Record 8 of Set 30 | grand-lahou
# Processing Record 9 of Set 30 | lobito
# Processing Record 10 of Set 30 | ust-nera
# Processing Record 11 of Set 30 | nicoya
# Processing Record 12 of Set 30 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 30 | nizhniy odes
# Processing Record 14 of Set 30 | belmonte
# Processing Record 15 of Set 30 | grand-santi
# Processing Record 16 of Set 30 | perelyub
# Processing Record 17 of Set 30 | gurskoye
# City not found. Skipping...
# Processing Record 18 of Set 30 | dana point
# Processing Record 19 of Set 30 | poum
# Processing Record 20 of Set 30 | bari
# Processing Record 21 of Set 30 | newport
# Processing Record 22 of Set 30 | weyburn
# Processing Record 23 of Set 30 | ginir
# Processing Record 24 of Set 30 | yeppoon
# Processing Record 25 of Set 30 | barcelos
# Processing Record 26 of Set 30 | beidao
# Processing Record 27 of Set 30 | omsukchan
# Processing Record 28 of Set 30 | karmaskaly
# Processing Record 29 of Set 30 | cruz alta
# Processing Record 30 of Set 30 | det udom
# Processing Record 31 of Set 30 | campbell river
# Processing Record 32 of Set 30 | the valley
# Processing Record 33 of Set 30 | olavarria
# Processing Record 34 of Set 30 | dali
# Processing Record 35 of Set 30 | roseburg
# Processing Record 36 of Set 30 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 30 | danjiangkou
# Processing Record 38 of Set 30 | huanan
# Processing Record 39 of Set 30 | hawalli
# Processing Record 40 of Set 30 | ochakiv
# Processing Record 41 of Set 30 | abha
# Processing Record 42 of Set 30 | satitoa
# City not found. Skipping...
# Processing Record 43 of Set 30 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 30 | aloleng
# Processing Record 45 of Set 30 | shuiji
# Processing Record 46 of Set 30 | cabra
# Processing Record 47 of Set 30 | noumea
# Processing Record 48 of Set 30 | baracoa
# Processing Record 49 of Set 30 | yuanping
# Processing Record 50 of Set 30 | phalombe
# Processing Record 1 of Set 31 | kendari
# Processing Record 2 of Set 31 | miles city
# Processing Record 3 of Set 31 | talikota
# Processing Record 4 of Set 31 | wahran
# City not found. Skipping...
# Processing Record 5 of Set 31 | pousat
# City not found. Skipping...
# Processing Record 6 of Set 31 | lyuban
# Processing Record 7 of Set 31 | ayan
# Processing Record 8 of Set 31 | pontevedra
# Processing Record 9 of Set 31 | banyo
# Processing Record 10 of Set 31 | raudeberg
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng Weather Description  Max Temp  \
# 0     Geraldton      AU -28.7667  114.6000          light rain     63.01
# 1       Rikitea      PF -23.1203 -134.9692           clear sky     74.43
# 2         Kapaa      US  22.0752 -159.3190       broken clouds     82.47
# 3  Puerto Ayora      EC  -0.7393  -90.3518       broken clouds     76.96
# 4       Mataura      NZ -46.1927  168.8643     overcast clouds     37.47
# 5  Kruisfontein      ZA -34.0033   24.7314     overcast clouds     53.89
# 6     Jamestown      US  42.0970  -79.2353       broken clouds     81.30
# 7          Hilo      US  19.7297 -155.0900          few clouds     82.26
# 8        Rawson      AR -43.3002  -65.1023           clear sky     46.44
# 9     Paranaiba      BR -19.6772  -51.1908          few clouds     75.61
#
#    Humidity  Cloudiness  Wind Speed
# 0        72          40       12.66
# 1        75           1       12.12
# 2        66          62        3.00
# 3        83          52        5.01
# 4        94          91        3.76
# 5        90         100        6.42
# 6        70          76        4.00
# 7        84          24        3.00
# 8        55           0        7.29
# 9        32          13        4.88

# %%
new_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
new_columns
# Out:
# ['City',
#  'Country',
#  'Lat',
#  'Lng',
#  'Max Temp',
#  'Humidity',
#  'Cloudiness',
#  'Wind Speed',
#  'Weather Description']

# %%
city_data_df = city_data_df[new_columns]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Geraldton      AU -28.7667  114.6000     63.01        72          40
# 1         Rikitea      PF -23.1203 -134.9692     74.43        75           1
# 2           Kapaa      US  22.0752 -159.3190     82.47        66          62
# 3    Puerto Ayora      EC  -0.7393  -90.3518     76.96        83          52
# 4         Mataura      NZ -46.1927  168.8643     37.47        94          91
# ..            ...     ...      ...       ...       ...       ...         ...
# 693        Lyuban      BY  52.7985   28.0048     63.34        94          89
# 694          Ayan      RU  56.4500  138.1667     56.14        53           4
# 695    Pontevedra      ES  42.4310   -8.6444     63.50        86          99
# 696         Banyo      CM   6.7500   11.8167     64.38        97         100
# 697     Raudeberg      NO  61.9875    5.1352     58.19        77           8
#
#      Wind Speed Weather Description
# 0         12.66          light rain
# 1         12.12           clear sky
# 2          3.00       broken clouds
# 3          5.01       broken clouds
# 4          3.76     overcast clouds
# ..          ...                 ...
# 693        6.42     overcast clouds
# 694        4.70           clear sky
# 695        3.91     overcast clouds
# 696        3.11          light rain
# 697        3.78           clear sky
#
# [698 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/myric/UCF_Projects/Mod_6/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
